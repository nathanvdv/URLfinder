# %% [markdown]
# # Load Parquet Files into DataFrames

# %%
import pandas as pd
import os
# Directory containing Parquet files
parquet_directory = 'ExtractedFiles'

# Initialize a dictionary to hold the DataFrames
dataframes = {}

# Check if the directory exists
if os.path.exists(parquet_directory):
    # List all Parquet files in the directory
    parquet_files = [f for f in os.listdir(parquet_directory) if f.endswith('.parquet')]

    # Process each Parquet file
    for parquet_file in parquet_files:
        filepath = os.path.join(parquet_directory, parquet_file)
        # Load the Parquet file into a DataFrame
        df = pd.read_parquet(filepath)
        
        # Add the DataFrame to the dictionary
        # Use the filename (without the extension) as the key
        key = os.path.splitext(parquet_file)[0]
        dataframes[key] = df

    print("Loaded DataFrames from Parquet files.")
else:
    print(f"Directory does not exist: {parquet_directory}")

# Iterate through each key, value pair in the dataframes dictionary
for key, df in dataframes.items():
    print(f"Information for DataFrame: {key}")
    # Use the info() method to print detailed information about the DataFrame
    df.info()
    #df.head()
    print("\n")  # Add a newline for better readability between DataFrame infos

# Iterate through each key, value pair in the dataframes dictionary
for key, df in dataframes.items():
    print(f"Head of DataFrame '{key}':")
    print(df.head())  # Print the first few rows of the DataFrame
    print("-" * 40)  # Print a separator for readability
# Out:
# Loaded DataFrames from Parquet files.
# Information for DataFrame: activity
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20472180 entries, 0 to 20472179
# Data columns (total 5 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   EntityNumber    object
#  1   ActivityGroup   int64
#  2   NaceVersion     int64
#  3   NaceCode        int64
#  4   Classification  object
# dtypes: int64(3), object(2)
# memory usage: 781.0+ MB
#
#
# Information for DataFrame: address
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2821223 entries, 0 to 2821222
# Data columns (total 13 columns):
#  #   Column            Dtype
# ---  ------            -----
#  0   EntityNumber      object
#  1   TypeOfAddress     object
#  2   CountryNL         object
#  3   CountryFR         object
#  4   Zipcode           object
#  5   MunicipalityNL    object
#  6   MunicipalityFR    object
#  7   StreetNL          object
#  8   StreetFR          object
#  9   HouseNumber       object
#  10  Box               object
#  11  ExtraAddressInfo  object
#  12  DateStrikingOff   object
# dtypes: object(13)
# memory usage: 279.8+ MB
#
#
# Information for DataFrame: branch
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7362 entries, 0 to 7361
# Data columns (total 3 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Id                7362 non-null   object
#  1   StartDate         7362 non-null   object
#  2   EnterpriseNumber  7362 non-null   object
# dtypes: object(3)
# memory usage: 172.7+ KB
#
#
# Information for DataFrame: code
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14948 entries, 0 to 14947
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Category     14948 non-null  object
#  1   Code         14948 non-null  object
#  2   Language     14948 non-null  object
#  3   Description  14948 non-null  object
# dtypes: object(4)
# memory usage: 467.3+ KB
#
#
# Information for DataFrame: contact
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 635678 entries, 0 to 635677
# Data columns (total 4 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   EntityNumber   635678 non-null  object
#  1   EntityContact  635678 non-null  object
#  2   ContactType    635678 non-null  object
#  3   Value          635678 non-null  object
# dtypes: object(4)
# memory usage: 19.4+ MB
#
#
# Information for DataFrame: denomination
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3252863 entries, 0 to 3252862
# Data columns (total 4 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   EntityNumber        object
#  1   Language            int64
#  2   TypeOfDenomination  int64
#  3   Denomination        object
# dtypes: int64(2), object(2)
# memory usage: 99.3+ MB
#
#
# Information for DataFrame: enterprise
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1924032 entries, 0 to 1924031
# Data columns (total 7 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   EnterpriseNumber    object
#  1   Status              object
#  2   JuridicalSituation  int64
#  3   TypeOfEnterprise    int64
#  4   JuridicalForm       float64
#  5   JuridicalFormCAC    float64
#  6   StartDate           object
# dtypes: float64(2), int64(2), object(3)
# memory usage: 102.8+ MB
#
#
# Information for DataFrame: establishment
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1660346 entries, 0 to 1660345
# Data columns (total 3 columns):
#  #   Column               Non-Null Count    Dtype
# ---  ------               --------------    -----
#  0   EstablishmentNumber  1660346 non-null  object
#  1   StartDate            1660346 non-null  object
#  2   EnterpriseNumber     1660346 non-null  object
# dtypes: object(3)
# memory usage: 38.0+ MB
#
#
# Information for DataFrame: filtered_dataset
# <class 'pandas.core.frame.DataFrame'>
# Index: 0 entries
# Data columns (total 1 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Denomination  0 non-null      object
# dtypes: object(1)
# memory usage: 0.0+ bytes
#
#
# Information for DataFrame: meta
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Variable  5 non-null      object
#  1   Value     5 non-null      object
# dtypes: object(2)
# memory usage: 212.0+ bytes
#
#
# Head of DataFrame 'activity':
#    EntityNumber  ActivityGroup  NaceVersion  NaceCode Classification
# 0  0200.065.765              6         2008     84130           MAIN
# 1  0200.065.765              1         2008     41101           MAIN
# 2  0200.065.765              1         2003     70111           MAIN
# 3  0200.068.636              6         2008     36000           MAIN
# 4  0200.068.636              1         2008     36000           MAIN
# ----------------------------------------
# Head of DataFrame 'address':
#    EntityNumber TypeOfAddress CountryNL CountryFR Zipcode  \
# 0  0200.065.765          REGO      None      None    9070
# 1  0200.068.636          REGO      None      None    9000
# 2  0200.171.970          REGO      None      None    9000
# 3  0200.245.711          REGO      None      None    9500
# 4  0200.305.493          REGO      None      None    9520
#
#         MunicipalityNL       MunicipalityFR        StreetNL        StreetFR  \
# 0         Destelbergen         Destelbergen   Panhuisstraat   Panhuisstraat
# 1                 Gent                 Gent     Stropstraat     Stropstraat
# 2                 Gent                 Gent      Brabantdam      Brabantdam
# 3       Geraardsbergen       Geraardsbergen  Hoge Buizemont  Hoge Buizemont
# 4  Sint-Lievens-Houtem  Sint-Lievens-Houtem  Gentsesteenweg  Gentsesteenweg
#
#   HouseNumber   Box ExtraAddressInfo DateStrikingOff
# 0           1  None             None            None
# 1           1  None             None            None
# 2         101  None             None            None
# 3         247  None             None            None
# 4          1B  None             None            None
# ----------------------------------------
# Head of DataFrame 'branch':
#               Id   StartDate EnterpriseNumber
# 0  9.000.006.626  01-09-1995     0257.883.408
# 1  9.000.008.210  01-01-1968     0400.051.358
# 2  9.000.008.705  01-01-1968     0400.067.095
# 3  9.000.009.594  01-01-1968     0400.150.140
# 4  9.000.011.574  30-04-1963     0400.291.680
# ----------------------------------------
# Head of DataFrame 'code':
#         Category Code Language        Description
# 0  ActivityGroup  001       FR      Activités TVA
# 1  ActivityGroup  001       NL   BTW-activiteiten
# 2  ActivityGroup  002       FR     Activités EDRL
# 3  ActivityGroup  002       NL  EDRL-activiteiten
# 4  ActivityGroup  003       FR          Activités
# ----------------------------------------
# Head of DataFrame 'contact':
#    EntityNumber EntityContact ContactType                       Value
# 0  0200.362.210           ENT       EMAIL    officiel.ic-inbw@inbw.be
# 1  0200.362.408           ENT         TEL                02 315 13 51
# 2  0200.362.408           ENT       EMAIL                info@isbw.be
# 3  0201.105.843           ENT       EMAIL    officiel.ic-idea@idea.be
# 4  0201.107.922           ENT       EMAIL  officiel.ic-irsia@irsia.be
# ----------------------------------------
# Head of DataFrame 'denomination':
#    EntityNumber  Language  TypeOfDenomination  \
# 0  0200.065.765         2                   1
# 1  0200.065.765         2                   2
# 2  0200.068.636         2                   1
# 3  0200.171.970         0                   1
# 4  0200.245.711         2                   1
#
#                            Denomination
# 0  Intergemeentelijke Vereniging Veneco
# 1                                Veneco
# 2                                 Farys
# 3     Sanatorium-Hospitaal van Lemberge
# 4  Intercommunaal Sanatorium Denderoord
# ----------------------------------------
# Head of DataFrame 'enterprise':
#   EnterpriseNumber Status  JuridicalSituation  TypeOfEnterprise  \
# 0     0200.065.765     AC                   0                 2
# 1     0200.068.636     AC                   0                 2
# 2     0200.171.970     AC                   0                 2
# 3     0200.245.711     AC                  12                 2
# 4     0200.305.493     AC                   0                 2
#
#    JuridicalForm  JuridicalFormCAC   StartDate
# 0          416.0               NaN  09-08-1960
# 1          417.0               NaN  16-02-1923
# 2          116.0               NaN  01-01-1968
# 3          116.0               NaN  01-01-1922
# 4          416.0               NaN  19-03-1962
# ----------------------------------------
# Head of DataFrame 'establishment':
#   EstablishmentNumber   StartDate EnterpriseNumber
# 0       2.000.000.339  01-11-1974     0403.449.823
# 1       2.000.000.438  01-09-1964     0403.590.274
# 2       2.000.001.032  17-01-1967     0403.174.758
# 3       2.000.001.428  01-09-1964     0400.395.016
# 4       2.000.001.824  01-08-1964     0404.314.608
# ----------------------------------------
# Head of DataFrame 'filtered_dataset':
# Empty DataFrame
# Columns: [Denomination]
# Index: []
# ----------------------------------------
# Head of DataFrame 'meta':
#            Variable                Value
# 0      SnapshotDate           01-03-2024
# 1  ExtractTimestamp  03-03-2024 08:19:27
# 2       ExtractType                 full
# 3     ExtractNumber                  121
# 4           Version                1.0.0
# ----------------------------------------

# %% [markdown]
# # Filtered DataFrame

# %%
import pandas as pd
import os
from functools import reduce

# Filtering for 'OfficialName'
official_name_df = dataframes['denomination'][
    (dataframes['denomination']['TypeOfDenomination'] == 1) & 
    (dataframes['denomination']['Language'] == 2)
][['Denomination', 'EntityNumber']].copy()  # Assuming 'Denomination' is the correct column to use

# Renaming column as per requirement
official_name_df.rename(columns={'Denomination': 'OfficialName'}, inplace=True)


abbreviation_df = dataframes['denomination'][
    (dataframes['denomination']['TypeOfDenomination'] == 2) & 
    (dataframes['denomination']['Language'] == 2)
][['Denomination', 'EntityNumber']].copy()  


abbreviation_df.rename(columns={'Denomination': 'Abbreviation'}, inplace=True)

tradeName_df = dataframes['denomination'][
    (dataframes['denomination']['TypeOfDenomination'] == 3) & 
    (dataframes['denomination']['Language'] == 2)
][['Denomination', 'EntityNumber']].copy()  

tradeName_df.rename(columns={'Denomination': 'TradeName'}, inplace=True)


zipcode_df = dataframes['address'][
    (dataframes['address']['TypeOfAddress'] == "REGO")
][['Zipcode', 'EntityNumber']].copy()  

zipcode_df.rename(columns={'Zipcode': 'ZipCode'}, inplace=True)


Municipality_df = dataframes['address'][
    (dataframes['address']['TypeOfAddress'] == "REGO")
][['MunicipalityNL', 'EntityNumber']].copy()  

Municipality_df.rename(columns={'MunicipalityNL': 'Municipality'}, inplace=True)


Street_df = dataframes['address'][
    (dataframes['address']['TypeOfAddress'] == "REGO")
][['StreetNL', 'EntityNumber']].copy()  

Street_df.rename(columns={'StreetNL': 'Street'}, inplace=True)


HouseNumber_df = dataframes['address'][
    (dataframes['address']['TypeOfAddress'] == "REGO")
][['HouseNumber', 'EntityNumber']].copy()  

HouseNumber_df.rename(columns={'HouseNumber': 'HouseNumber'}, inplace=True)

Email_df = dataframes['contact'][
    (dataframes['contact']['EntityContact'].isin(['ENT', 'EST'])) & 
    (dataframes['contact']['ContactType'] == 'EMAIL')
][['Value', 'EntityNumber']].copy()

Email_df.rename(columns={'Value': 'Email'}, inplace=True)

Tel_df = dataframes['contact'][
    (dataframes['contact']['EntityContact'].isin(['ENT', 'EST'])) & 
    (dataframes['contact']['ContactType'] == 'TEL')
][['Value', 'EntityNumber']].copy()

Tel_df.rename(columns={'Value': 'TEL'}, inplace=True)

URL_df = dataframes['contact'][
    (dataframes['contact']['EntityContact'].isin(['ENT', 'EST'])) & 
    (dataframes['contact']['ContactType'] == 'WEB')
][['Value', 'EntityNumber']].copy()

URL_df.rename(columns={'Value': 'URL'}, inplace=True)


# Combining the filtered DataFrames
# Assuming df_list is a list of your DataFrames
df_list = [official_name_df, abbreviation_df, tradeName_df,zipcode_df, Municipality_df, Street_df, HouseNumber_df, Email_df, Tel_df, URL_df]

# Using reduce to merge all DataFrames in the list based on 'EntityNumber'
combined_df = reduce(lambda left, right: pd.merge(left, right, on='EntityNumber', how='outer'), df_list)

# Now, 'EntityNumber' can be set as the index in the combined DataFrame
combined_df.set_index('EntityNumber', inplace=True)

# %% [markdown]
# # Filtering

# %%
# Step 1: Identify rows in 'address' DataFrame with missing 'CountryNL' values
missing_country_nl = dataframes['address']['CountryNL'].isna()

# Extract 'EntityNumber' for rows where 'CountryNL' is missing
missing_entities = dataframes['address'][missing_country_nl]['EntityNumber']

# Step 2: Filter these 'EntityNumber's out of your main dataset 'final_df'
# Assuming 'final_df' has 'EntityNumber' as its index or a column
if 'EntityNumber' in combined_df.columns:
    # If 'EntityNumber' is a column in 'final_df'
    final_df_filtered = combined_df[~combined_df['EntityNumber'].isin(missing_entities)]
else:
    # If 'EntityNumber' is the index in 'final_df'
    final_df_filtered = combined_df[~combined_df.index.isin(missing_entities)]

# %% [markdown]
# # Saving the combined dataset

# %%
# Define the path for the new combined Parquet file in your directory
new_combined_parquet_file_path = './combined_filtered_dataset.parquet'

# Save the combined DataFrame as a Parquet file
combined_df.to_parquet(new_combined_parquet_file_path)

print(f"Combined and filtered DataFrame saved as Parquet file at: {new_combined_parquet_file_path}")
# Out:
# Combined and filtered DataFrame saved as Parquet file at: ./combined_filtered_dataset.parquet

# %%
print(combined_df.info())
print(combined_df.head(50))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2085477 entries, 0200.065.765 to 2.356.182.359
# Data columns (total 10 columns):
#  #   Column        Dtype
# ---  ------        -----
#  0   OfficialName  object
#  1   Abbreviation  object
#  2   TradeName     object
#  3   ZipCode       object
#  4   Municipality  object
#  5   Street        object
#  6   HouseNumber   object
#  7   Email         object
#  8   TEL           object
#  9   URL           object
# dtypes: object(10)
# memory usage: 239.5+ MB
# None
#                                                    OfficialName Abbreviation  \
# EntityNumber
# 0200.065.765               Intergemeentelijke Vereniging Veneco       Veneco
# 0200.068.636                                              Farys          NaN
# 0200.245.711               Intercommunaal Sanatorium Denderoord   DENDEROORD
# 0200.305.493  Intergemeentelijk Samenwerkingsverband voor ru...        SOLVA
# 0200.420.608      Congregatie der Gasthuiszusters van Poperinge          NaN
# 0200.448.421         Liefdadige Congregatie der Gasthuiszusters          NaN
# 0200.450.005  Liefdadige Congregatie der Zwarte Zusters van ...          NaN
# 0200.762.878                                            VLOTTER          NaN
# 0200.881.951  Intercommunale Maatschappij voor de Ruimtelijk...     HAVILAND
# 0201.310.731  NOORDLIMBURGSE MAATSCHAPPIJ VOOR DE OPRICHTING...    NOLIMPARK
# 0201.310.929                                                IGL          IGL
# 0201.311.028  Intercommunale Maatschappij voor Ruimtelijke O...       I.M.L.
# 0201.311.226                                            FLUVIUS          NaN
# 0202.082.078  Intercommunale van Brabant voor Electriciteit ...          NaN
# 0202.239.951                                           PROXIMUS          NaN
# 0202.962.701                                            VIVAQUA          NaN
# 0203.071.973                                            BRULABO          NaN
# 0203.201.340                          Nationale Bank van België          NaN
# 0203.211.040  HOLDING COMMUNAL - GEMEENTELIJKE HOLDING - GEM...          NaN
# 0203.286.759                                         Delcredere          NaN
# 0203.389.204    Société Coopérative Intercommunale de Crémation      Cremabu
# 0203.430.576    NATIONALE MAATSCHAPPIJ DER BELGISCHE SPOORWEGEN         NMBS
# 0203.563.111          Provinciale Brabantse Energiemaatschappij       P.B.E.
# 0204.212.714  Interkommunale Ontwikkelingsmaatschappij voor ...       I.O.K.
# 0204.908.936                                              Pidpa          NaN
# 0204.923.881                                         Water-link          NaN
# 0205.097.392                Maatschappij van de Brugse Zeehaven          MBZ
# 0205.157.176                                       Fluvius West          NaN
# 0205.157.869                        West-Vlaamse Intercommunale          WVI
# 0205.264.668  Intercommunale Waterleidingsmaatschappij van V...     I.W.V.A.
# 0205.350.681                             INTERCOMMUNALE LEIEDAL          NaN
# 0205.764.318                                             CRELAN          NaN
# 0205.774.810  Intercommunale Maatschappij voor de Ruimtelijk...  INTERLEUVEN
# 0205.970.788  Intercommunale maatschappij voor de Sanering e...          NaN
# 0206.460.639  Intergemeentelijk Samenwerkingsverband van het...    Interwaas
# 0206.561.993                            Gemeente Steenokkerzeel          NaN
# 0206.562.092                                 Gemeente Hoeilaart          NaN
# 0206.582.284                                Gemeente Anderlecht          NaN
# 0206.636.526                                    Gemeente Nijlen          NaN
# 0206.653.946  Rijksinstituut voor Ziekte- en Invaliditeitsve...        RIZIV
# 0206.677.801                                Gemeente Brasschaat          NaN
# 0206.677.997                                   Gemeente Schoten          NaN
# 0206.684.927                                  Stad Blankenberge          NaN
# 0206.695.419  Anglicaanse Kerkfabriek - Verenigde Anglicaans...          NaN
# 0206.731.645                 Rijksdienst voor Sociale Zekerheid          RSZ
# 0206.731.744                   Voorzorgskas voor de Mijnwerkers          NaN
# 0206.732.338  Vast Bureau voor Nationale Werken voor Oorlogs...          NaN
# 0206.732.437   Hulpkas voor Ziekte- en Invaliditeitsverzekering         HZIV
# 0206.732.536              Hulpkas voor Werkloosheidsuitkeringen          HVW
# 0206.732.932               Rijksdienst voor Jaarlijkse Vakantie          RJV
#
#                                                       TradeName ZipCode  \
# EntityNumber
# 0200.065.765                                                NaN    9070
# 0200.068.636                                                NaN    9000
# 0200.245.711                                                NaN    9500
# 0200.305.493                                                NaN    9520
# 0200.420.608                                                NaN    8970
# 0200.448.421                                                NaN    8500
# 0200.450.005                                                NaN    8000
# 0200.762.878                                                NaN    2850
# 0200.881.951                                                NaN    1731
# 0201.310.731                                                NaN    3900
# 0201.310.929                                                NaN    3600
# 0201.311.028                                                NaN    3640
# 0201.311.226                                                NaN    3500
# 0202.082.078                                                NaN    1800
# 0202.239.951                                                NaN    1030
# 0202.962.701                                                NaN    1000
# 0203.071.973                                                NaN    1000
# 0203.201.340                                                NaN    1000
# 0203.211.040                                                NaN    1000
# 0203.286.759                                                NaN    1000
# 0203.389.204  Intercommunale coöperative vennootschap voor C...    1180
# 0203.430.576                                                NaN    1060
# 0203.563.111                                                NaN    3210
# 0204.212.714                                                NaN    2440
# 0204.908.936                                                NaN    2280
# 0204.923.881                                                NaN    2018
# 0205.097.392                                                NaN    8380
# 0205.157.176                                                NaN    8820
# 0205.157.869                                                NaN    8310
# 0205.264.668                                                NaN    8670
# 0205.350.681                                          405350627    8500
# 0205.764.318                                                NaN    1070
# 0205.774.810                                                NaN    3000
# 0205.970.788                                                NaN    1800
# 0206.460.639                                                NaN    9100
# 0206.561.993                                                NaN    1820
# 0206.562.092                                                NaN    1560
# 0206.582.284                                                NaN    1070
# 0206.636.526                                                NaN    2560
# 0206.653.946                                                NaN    1210
# 0206.677.801                                                NaN    2930
# 0206.677.997                                                NaN    2900
# 0206.684.927                                                NaN    8370
# 0206.695.419                                                NaN    1050
# 0206.731.645                                                NaN    1060
# 0206.731.744                                                NaN    1050
# 0206.732.338                                                NaN    1000
# 0206.732.437                                                NaN    1000
# 0206.732.536                                                NaN    1210
# 0206.732.932                                                NaN    1000
#
#                            Municipality                      Street  \
# EntityNumber
# 0200.065.765               Destelbergen               Panhuisstraat
# 0200.068.636                       Gent                 Stropstraat
# 0200.245.711             Geraardsbergen              Hoge Buizemont
# 0200.305.493        Sint-Lievens-Houtem              Gentsesteenweg
# 0200.420.608                  Poperinge                 Ieperstraat
# 0200.448.421                   Kortrijk             Budastraat(Kor)
# 0200.450.005                     Brugge               Woensdagmarkt
# 0200.762.878                       Boom     Colonel Silvertopstraat
# 0200.881.951                       Asse           Brusselsesteenweg
# 0201.310.731                       Pelt                  Oude Markt
# 0201.310.929                       Genk                  Klotstraat
# 0201.311.028                    Kinrooi              Maasdijk (Oph)
# 0201.311.226                    Hasselt            Trichterheideweg
# 0202.082.078                  Vilvoorde                 Grote Markt
# 0202.239.951                 Schaarbeek        Koning AlbertII laan
# 0202.962.701                    Brussel                Keizerinlaan
# 0203.071.973                    Brussel                Maalbeeklaan
# 0203.201.340                    Brussel           de Berlaimontlaan
# 0203.211.040                    Brussel                   Kunstlaan
# 0203.286.759                    Brussel              Montoyerstraat
# 0203.389.204                      Ukkel                  Stillelaan
# 0203.430.576  Sint-Gillis (bij-Brussel)             Frankrijkstraat
# 0203.563.111                    Lubbeek        Diestsesteenweg(LIN)
# 0204.212.714                       Geel                Antwerpseweg
# 0204.908.936                Grobbendonk              Vierselse baan
# 0204.923.881                  Antwerpen            Mechelsesteenweg
# 0205.097.392                     Brugge                Isabellalaan
# 0205.157.176                    Torhout                   Noordlaan
# 0205.157.869                     Brugge           Baron Ruzettelaan
# 0205.264.668                   Koksijde       Doornpannestraat(Odk)
# 0205.350.681                   Kortrijk  President Kennedypark(Kor)
# 0205.764.318                 Anderlecht          Sylvain Dupuislaan
# 0205.774.810                     Leuven              Brouwersstraat
# 0205.970.788                  Vilvoorde                   Medialaan
# 0206.460.639               Sint-Niklaas                   Lamstraat
# 0206.561.993             Steenokkerzeel              Orchideeënlaan
# 0206.562.092                  Hoeilaart       Jan van Ruusbroecpark
# 0206.582.284                 Anderlecht                  Raadsplein
# 0206.636.526                     Nijlen                  Kerkstraat
# 0206.653.946        Sint-Joost-ten-Node                 Galileelaan
# 0206.677.801                 Brasschaat                Verhoevenlei
# 0206.677.997                    Schoten               Verbertstraat
# 0206.684.927               Blankenberge           J.F. Kennedyplein
# 0206.695.419                     Elsene      Kapitein Crespelstraat
# 0206.731.645  Sint-Gillis (bij-Brussel)           Victor Hortaplein
# 0206.731.744                     Elsene               Stefaniaplein
# 0206.732.338                    Brussel              Montoyerstraat
# 0206.732.437                    Brussel                 Troonstraat
# 0206.732.536        Sint-Joost-ten-Node               Brabantstraat
# 0206.732.932                    Brussel                 Warmoesberg
#
#              HouseNumber                         Email           TEL  \
# EntityNumber
# 0200.065.765           1                           NaN           NaN
# 0200.068.636           1                           NaN           NaN
# 0200.245.711         247                           NaN           NaN
# 0200.305.493          1B                           NaN           NaN
# 0200.420.608         134                           NaN           NaN
# 0200.448.421          37                           NaN           NaN
# 0200.450.005           6                           NaN           NaN
# 0200.762.878          15                           NaN           NaN
# 0200.881.951         617                           NaN           NaN
# 0201.310.731           2                           NaN           NaN
# 0201.310.929         125                           NaN  089/32.39.50
# 0201.311.028           1                           NaN           NaN
# 0201.311.226           8                           NaN           NaN
# 0202.082.078         Z/N                           NaN           NaN
# 0202.239.951          27                           NaN     022024111
# 0202.962.701       17-19                           NaN           NaN
# 0203.071.973           3                           NaN           NaN
# 0203.201.340          14                   info@nbb.be  02 221 21 11
# 0203.211.040          56                           NaN           NaN
# 0203.286.759           3                           NaN  02 788 88 00
# 0203.389.204          61         directeur@cremabru.be  02/376 76 43
# 0203.430.576          56                           NaN           NaN
# 0203.563.111         126                           NaN           NaN
# 0204.212.714           1                           NaN           NaN
# 0204.908.936           5                           NaN           NaN
# 0204.923.881          66                           NaN           NaN
# 0205.097.392           1                           NaN           NaN
# 0205.157.176           9                           NaN           NaN
# 0205.157.869          35                           NaN           NaN
# 0205.264.668           1                           NaN           NaN
# 0205.350.681          10                           NaN           NaN
# 0205.764.318         251                info@crelan.be  02/558.71.11
# 0205.774.810           6                           NaN           NaN
# 0205.970.788          28                           NaN           NaN
# 0206.460.639         113             info@interwaas.be  03/500 47 00
# 0206.561.993          17                           NaN           NaN
# 0206.562.092           -                           NaN           NaN
# 0206.582.284           1                           NaN           NaN
# 0206.636.526           4                           NaN           NaN
# 0206.653.946           5   communication@inami.fgov.be   +3225249797
# 0206.677.801          11                           NaN           NaN
# 0206.677.997           3                           NaN           NaN
# 0206.684.927           1                           NaN           NaN
# 0206.695.419          29                           NaN           NaN
# 0206.731.645          11  webmaster@onssrszlss.fgov.be   +3225095959
# 0206.731.744           6                           NaN           NaN
# 0206.732.338          61                           NaN           NaN
# 0206.732.437        30 A       info@caami-hziv.fgov.be   +3222293500
# 0206.732.536          62        info@hvw-capac.fgov.be   +3222091300
# 0206.732.932          48         onva@onva-rjv.fgov.be   +3226279765
#
#                                  URL
# EntityNumber
# 0200.065.765                     NaN
# 0200.068.636                     NaN
# 0200.245.711                     NaN
# 0200.305.493                     NaN
# 0200.420.608                     NaN
# 0200.448.421                     NaN
# 0200.450.005                     NaN
# 0200.762.878                     NaN
# 0200.881.951                     NaN
# 0201.310.731                     NaN
# 0201.310.929  extranet.iglimburg.be/
# 0201.311.028                     NaN
# 0201.311.226                     NaN
# 0202.082.078                     NaN
# 0202.239.951        www.proximus.com
# 0202.962.701                     NaN
# 0203.071.973                     NaN
# 0203.201.340              www.nbb.be
# 0203.211.040                     NaN
# 0203.286.759                     NaN
# 0203.389.204                     NaN
# 0203.430.576                     NaN
# 0203.563.111                     NaN
# 0204.212.714                     NaN
# 0204.908.936                     NaN
# 0204.923.881                     NaN
# 0205.097.392                     NaN
# 0205.157.176                     NaN
# 0205.157.869                     NaN
# 0205.264.668                     NaN
# 0205.350.681                     NaN
# 0205.764.318                     NaN
# 0205.774.810                     NaN
# 0205.970.788                     NaN
# 0206.460.639        www.interwaas.be
# 0206.561.993                     NaN
# 0206.562.092                     NaN
# 0206.582.284                     NaN
# 0206.636.526                     NaN
# 0206.653.946       www.inami.fgov.be
# 0206.677.801                     NaN
# 0206.677.997                     NaN
# 0206.684.927                     NaN
# 0206.695.419                     NaN
# 0206.731.645  www.onssrszlss.fgov.be
# 0206.731.744                     NaN
# 0206.732.338                     NaN
# 0206.732.437  www.caami-hziv.fgov.be
# 0206.732.536         www.hvw.fgov.be
# 0206.732.932    www.onva-rjv.fgov.be
